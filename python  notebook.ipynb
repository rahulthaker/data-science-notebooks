# %%
import pandas as pd

# %%
csv_path="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/projects/coursera_project/clean_gdp.csv"
df=pd.read_csv(csv_path)
df.head()
# Out:
#    date  level-current  level-chained  change-current  change-chained
# 0  1948          274.8         2020.0            -0.7            -0.6
# 1  1949          272.8         2008.9            10.0             8.7
# 2  1950          300.2         2184.0            15.7             8.0
# 3  1951          347.3         2360.0             5.9             4.1
# 4  1952          367.7         2456.1             6.0             4.7

# %%
csv_unemployement_path='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/projects/coursera_project/clean_unemployment.csv'
df1=pd.read_csv(csv_unemployement_path)
df1.head()
# Out:
#    date  unemployment
# 0  1948      3.750000
# 1  1949      6.050000
# 2  1950      5.208333
# 3  1951      3.283333
# 4  1952      3.025000

# %%
df8=df1[df1['unemployment']>8.5]
#df1 is the data frame which stores the csv file for unemployement created in the cell above
df8
# Out:
#     date  unemployment
# 34  1982      9.708333
# 35  1983      9.600000
# 61  2009      9.283333
# 62  2010      9.608333
# 63  2011      8.933333

# %%
import pandas as pd
from bokeh.plotting import figure, output_file, show,output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
def make_dashboard(x, gdp_change, unemployment, title, file_name):
    output_file(file_name)
    p = figure(title=title, x_axis_label='year', y_axis_label='%')
    p.line(x.squeeze(), gdp_change.squeeze(), color="firebrick", line_width=4, legend="% GDP change")
    p.line(x.squeeze(), unemployment.squeeze(), line_width=4, legend="% unemployed")
    show(p)

# %%
x = df[['date']]
gdp_change = df[['change-current']]
unemployment = df1[['unemployment']]
title = 'GDP_Dashboard'
file_name = "index.html"

# %%
make_dashboard(x=x, gdp_change=gdp_change, unemployment=unemployment, title=title, file_name=file_name)
# Out:
#   <div class="bk-root" id="e61b5a86-6119-4ca3-9975-f8670e11d690" data-root-id="1003"></div>
